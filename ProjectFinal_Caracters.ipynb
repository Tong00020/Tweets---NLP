# %% [markdown]
# # NLP of tweets

# %%
# !pip install openml

# %%
import nltk
import pandas as pd
import re
import numpy as np
import math
import openml
import sklearn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense,Activation
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.metrics import classification_report

# %% [markdown]
# ##Load Data

# %%
#https://www.openml.org/search?type=data&status=active&id=43397

data = openml.datasets.get_dataset(43397)
print(
    f"Dataset of '{data.name}'"
)
print(f"URL: {data.url}")
# Out:
# WARNING:root:Received uncompressed content from OpenML for https://api.openml.org/data/v1/download/22102222/Airlines-Tweets-Sentiments.arff.
# Dataset of 'Airlines-Tweets-Sentiments'
# URL: https://api.openml.org/data/v1/download/22102222/Airlines-Tweets-Sentiments.arff

# %%
X, y, categorical_indicator, attributes = data.get_data(
    dataset_format="dataframe", target=data.default_target_attribute
)
dataset = pd.DataFrame(X, columns=attributes)
dataset
# Out:
#                            _id  \
# 0     595e60b48fcd022a715f7b7b
# 1     595e60de8fcd022a715f7b7d
# 2     595e61448fcd022a715f7b7f
# 3     595e62748fcd022a715f7b83
# 4     595e62b28fcd022a715f7b86
# ...                        ...
# 1092  596b9c77976f440300c0f913
# 1093  596be744976f440300c0f9b7
# 1094  596c5d0f976f440300c0fac6
# 1095  596c9962976f440300c0fc90
# 1096  596cbbf1976f440300c0fdb5
#
#                                              tweet_text tweet_lang  \
# 0     this airfrance b777-300er has the oldest ifes ...         en
# 1     ???? will miss my connection airfrance https:/...         en
# 2     airfrance lost luggage in overhead cabin, emai...         en
# 3     here's a new twist on the "all airlines hate m...         en
# 4     airfrance so now i might not have 3 pieces of ...         en
# ...                                                 ...        ...
# 1092                           airfrance thanks in rome         en
# 1093  rakiichak you are flying the wrong airline, ai...         en
# 1094  kislanykim airfrance i has a similar experienc...         en
# 1095  nothing tops when you check the air france mus...         en
# 1096  ??la gastronomie...in the air  afrofoodie ??ai...         en
#
#       tweet_sentiment_value
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ...                     ...
# 1092                      2
# 1093                      2
# 1094                      2
# 1095                      2
# 1096                      2
#
# [1097 rows x 4 columns]

# %%
Y = X['tweet_sentiment_value']

# %% [markdown]
# ##Pre processing

# %%
X['tweet_text'] = X['tweet_text'].apply(lambda x: ' '.join([i for i in x.split() if len(i)>3]))

# %%
texts = X['tweet_text']
texts
# Out:
# 0       this airfrance b777-300er oldest ifes i've eve...
# 1       ???? will miss connection airfrance https://t....
# 2       airfrance lost luggage overhead cabin, email r...
# 3       here's twist "all airlines hate musicians" sag...
# 4       airfrance might have pieces most important gea...
#                               ...
# 1092                                airfrance thanks rome
# 1093    rakiichak flying wrong airline, france sensati...
# 1094    kislanykim airfrance similar experience with t...
# 1095    nothing tops when check france music selection...
# 1096    ??la gastronomie...in afrofoodie ??air france ...
# Name: tweet_text, Length: 1097, dtype: object

# %%
texts[1]
# Out:
# '???? will miss connection airfrance https://t.co/2olmtwcxyk'

# %%
def preprocessing(texts):
  t = re.sub(r'#','',texts)
  t = re.sub(r'hahaha','',texts)
  t = re.sub(r'\n','',texts)
  t = t.lower()
  t = re.sub(r'https:\/\/.*|http:\/\/.*','',texts)
  t = re.sub(r'[\,\+\=\-\_\?\[\]\{\}\@\.\'\$\!\&\>\<\;\"\(\)\:\/\\]+','',t)
  t = re.sub(r'[0-9]+','',t)
  return t

# %% [markdown]
# Remove stopwords

# %%
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('punkt')
stop_list_nltk = nltk.corpus.stopwords.words('english')

new_texts = []
for t in texts:
    if t not in stop_list_nltk:
        new_texts.append(t)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
vocabulary = {}

for i in range(0,len(new_texts)):
    new_texts[i] = new_texts[i].lower()
    for j in new_texts[i].split():
        if j not in vocabulary:
            vocabulary[j] = 1
        else:
            vocabulary[j]+=1

# %%
vocab_size = len(vocabulary)

# %% [markdown]
# Tokenization

# %%
tokenizer = Tokenizer(num_words = vocab_size,lower=True)
tokenizer.fit_on_texts(new_texts)

train_sequences = tokenizer.texts_to_sequences(new_texts)

# %%
train_sequences

# %% [markdown]
# Lemmatizing

# %%
from nltk.stem.porter import *
from nltk.stem import WordNetLemmatizer

corpus = []
nltk.download('wordnet')
nltk.download('omw-1.4')
lemmatizer = WordNetLemmatizer()
texts = [lemmatizer.lemmatize(w) for w in texts]

for text in new_texts:
  ptext = preprocessing(text)
  corpus.append(ptext)
corpus

# %%
corpus[1]
# Out:
# ' will miss connection airfrance '

# %% [markdown]
# ##Feature extraction

# %% [markdown]
# Bag-of-Words (BoW)

# %%
bag = " ".join(corpus)

# %%
tokens = bag.split()
vocab = sorted(set(tokens))

# %%
vocab

# %%
count_words = {}

for doc in corpus:
    words= nltk.word_tokenize(doc)
    for i in words:
        if i in count_words.keys():
            count_words[i] += 1
        else:
            count_words[i] = 1

# %% [markdown]
# Using Bag-of-Words wee can see which words are more used in the tweets

# %%
import heapq
from sklearn import tree

freq_words = heapq.nlargest(50,count_words, key=count_words.get)
freq_words
# Out:
# ['airfrance',
#  'france',
#  'flight',
#  'have',
#  'with',
#  'this',
#  'your',
#  'from',
#  'delta',
#  'paris',
#  'that',
#  'luggage',
#  'they',
#  'amp',
#  'been',
#  'service',
#  'still',
#  'thanks',
#  'will',
#  'airline',
#  'thank',
#  'customer',
#  'dont',
#  'hours',
#  'when',
#  'flying',
#  'were',
#  'check',
#  'airport',
#  'help',
#  'what',
#  'time',
#  'a',
#  'never',
#  'just',
#  'plane',
#  'experience',
#  'about',
#  'lost',
#  'there',
#  'delayed',
#  'business',
#  'over',
#  'baggage',
#  'af',
#  'please',
#  'after',
#  'its',
#  'staff',
#  'only']

# %% [markdown]
# Inverse Document Frequency (TF-IDF)

# %%
words_freq = {}
pondered_freq = {}
N = {} 

for i,j in enumerate(corpus):
    words_freq[i] = dict()
    pondered_freq[i] = dict()
    N[i] = len(j.split())
    for word in j.split():
        if word in words_freq[i]:
            words_freq[i][word] += 1
        else:
            words_freq[i][word] = 1

        if word in pondered_freq[i]:
            pondered_freq[i][word] += 1
        else:
            pondered_freq[i][word] = 1

for i in pondered_freq:
    for word in pondered_freq[i]:
        pondered_freq[i][word] /= N[doc]

# %%
idf = {}
tf_idf = {}

for word in vocab:
    idf[word] = 0
    for i in words_freq:
        if word in words_freq[i]:
            idf[word] += 1

for word in idf:
      idf[word] = math.log(len(corpus)/idf[word])

for i in pondered_freq:
    tf_idf[i] = dict()
    for word in pondered_freq[i]:
        tf_idf[i][word] = pondered_freq[i][word]*idf[word]

# %%
df = pd.DataFrame().from_records(tf_idf).fillna(0).T
df
# Out:
#          this  airfrance       ber    oldest      ifes       ive      ever  \
# 0     0.29692   0.037604  0.788398  0.875042  0.875042  0.483105  0.506987
# 1     0.00000   0.037604  0.000000  0.000000  0.000000  0.000000  0.000000
# 2     0.00000   0.037604  0.000000  0.000000  0.000000  0.000000  0.000000
# 3     0.00000   0.037604  0.000000  0.000000  0.000000  0.000000  0.000000
# 4     0.00000   0.075209  0.000000  0.000000  0.000000  0.483105  0.506987
# ...       ...        ...       ...       ...       ...       ...       ...
# 1092  0.00000   0.037604  0.000000  0.000000  0.000000  0.000000  0.000000
# 1093  0.00000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1094  0.00000   0.075209  0.000000  0.000000  0.000000  0.000000  0.000000
# 1095  0.00000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1096  0.00000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#           seen   belongs    museum  ...  rakiichak  sensational  kislanykim  \
# 0     0.631803  0.737715  0.875042  ...   0.000000     0.000000    0.000000
# 1     0.000000  0.000000  0.000000  ...   0.000000     0.000000    0.000000
# 2     0.000000  0.000000  0.000000  ...   0.000000     0.000000    0.000000
# 3     0.000000  0.000000  0.000000  ...   0.000000     0.000000    0.000000
# 4     0.000000  0.000000  0.000000  ...   0.000000     0.000000    0.000000
# ...        ...       ...       ...  ...        ...          ...         ...
# 1092  0.000000  0.000000  0.000000  ...   0.000000     0.000000    0.000000
# 1093  0.000000  0.000000  0.000000  ...   0.875042     0.875042    0.000000
# 1094  0.000000  0.000000  0.000000  ...   0.000000     0.000000    0.875042
# 1095  0.000000  0.000000  0.000000  ...   0.000000     0.000000    0.000000
# 1096  0.000000  0.000000  0.000000  ...   0.000000     0.000000    0.000000
#
#         laxcdg      tops  yourself    screen  gastronomiein  afrofoodie  \
# 0     0.000000  0.000000  0.000000  0.000000       0.000000    0.000000
# 1     0.000000  0.000000  0.000000  0.000000       0.000000    0.000000
# 2     0.000000  0.000000  0.000000  0.000000       0.000000    0.000000
# 3     0.000000  0.000000  0.000000  0.000000       0.000000    0.000000
# 4     0.000000  0.000000  0.000000  0.000000       0.000000    0.000000
# ...        ...       ...       ...       ...            ...         ...
# 1092  0.000000  0.000000  0.000000  0.000000       0.000000    0.000000
# 1093  0.000000  0.000000  0.000000  0.000000       0.000000    0.000000
# 1094  0.875042  0.000000  0.000000  0.000000       0.000000    0.000000
# 1095  0.000000  0.875042  0.875042  0.875042       0.000000    0.000000
# 1096  0.000000  0.000000  0.000000  0.000000       0.875042    0.875042
#
#       philippeloretstudios
# 0                 0.000000
# 1                 0.000000
# 2                 0.000000
# 3                 0.000000
# 4                 0.000000
# ...                    ...
# 1092              0.000000
# 1093              0.000000
# 1094              0.000000
# 1095              0.000000
# 1096              0.875042
#
# [1097 rows x 3007 columns]

# %%
df_term_frequency = df.multiply(idf)
df_term_frequency
# Out:
#           this  airfrance       ber    oldest      ifes       ive      ever  \
# 0     0.705293   0.011313  4.972576  6.125585  6.125585  1.867124  2.056286
# 1     0.000000   0.011313  0.000000  0.000000  0.000000  0.000000  0.000000
# 2     0.000000   0.011313  0.000000  0.000000  0.000000  0.000000  0.000000
# 3     0.000000   0.011313  0.000000  0.000000  0.000000  0.000000  0.000000
# 4     0.000000   0.022625  0.000000  0.000000  0.000000  1.867124  2.056286
# ...        ...        ...       ...       ...       ...       ...       ...
# 1092  0.000000   0.011313  0.000000  0.000000  0.000000  0.000000  0.000000
# 1093  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1094  0.000000   0.022625  0.000000  0.000000  0.000000  0.000000  0.000000
# 1095  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1096  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#           seen   belongs    museum  ...  rakiichak  sensational  kislanykim  \
# 0     3.193401  4.353791  6.125585  ...   0.000000     0.000000    0.000000
# 1     0.000000  0.000000  0.000000  ...   0.000000     0.000000    0.000000
# 2     0.000000  0.000000  0.000000  ...   0.000000     0.000000    0.000000
# 3     0.000000  0.000000  0.000000  ...   0.000000     0.000000    0.000000
# 4     0.000000  0.000000  0.000000  ...   0.000000     0.000000    0.000000
# ...        ...       ...       ...  ...        ...          ...         ...
# 1092  0.000000  0.000000  0.000000  ...   0.000000     0.000000    0.000000
# 1093  0.000000  0.000000  0.000000  ...   6.125585     6.125585    0.000000
# 1094  0.000000  0.000000  0.000000  ...   0.000000     0.000000    6.125585
# 1095  0.000000  0.000000  0.000000  ...   0.000000     0.000000    0.000000
# 1096  0.000000  0.000000  0.000000  ...   0.000000     0.000000    0.000000
#
#         laxcdg      tops  yourself    screen  gastronomiein  afrofoodie  \
# 0     0.000000  0.000000  0.000000  0.000000       0.000000    0.000000
# 1     0.000000  0.000000  0.000000  0.000000       0.000000    0.000000
# 2     0.000000  0.000000  0.000000  0.000000       0.000000    0.000000
# 3     0.000000  0.000000  0.000000  0.000000       0.000000    0.000000
# 4     0.000000  0.000000  0.000000  0.000000       0.000000    0.000000
# ...        ...       ...       ...       ...            ...         ...
# 1092  0.000000  0.000000  0.000000  0.000000       0.000000    0.000000
# 1093  0.000000  0.000000  0.000000  0.000000       0.000000    0.000000
# 1094  6.125585  0.000000  0.000000  0.000000       0.000000    0.000000
# 1095  0.000000  6.125585  6.125585  6.125585       0.000000    0.000000
# 1096  0.000000  0.000000  0.000000  0.000000       6.125585    6.125585
#
#       philippeloretstudios
# 0                 0.000000
# 1                 0.000000
# 2                 0.000000
# 3                 0.000000
# 4                 0.000000
# ...                    ...
# 1092              0.000000
# 1093              0.000000
# 1094              0.000000
# 1095              0.000000
# 1096              6.125585
#
# [1097 rows x 3007 columns]

# %%
df2csv = pd.DataFrame({'id' : X['_id'],
                   'tweets': corpus,
                   'tweet_sentiment_value': Y})
df2csv
# Out:
#                             id  \
# 0     595e60b48fcd022a715f7b7b
# 1     595e60de8fcd022a715f7b7d
# 2     595e61448fcd022a715f7b7f
# 3     595e62748fcd022a715f7b83
# 4     595e62b28fcd022a715f7b86
# ...                        ...
# 1092  596b9c77976f440300c0f913
# 1093  596be744976f440300c0f9b7
# 1094  596c5d0f976f440300c0fac6
# 1095  596c9962976f440300c0fc90
# 1096  596cbbf1976f440300c0fdb5
#
#                                                  tweets  tweet_sentiment_value
# 0     this airfrance ber oldest ifes ive ever seen b...                      0
# 1                       will miss connection airfrance                       0
# 2     airfrance lost luggage overhead cabin email re...                      0
# 3     heres twist all airlines hate musicians saga g...                      0
# 4     airfrance might have pieces most important gea...                      0
# ...                                                 ...                    ...
# 1092                              airfrance thanks rome                      2
# 1093  rakiichak flying wrong airline france sensational                      2
# 1094  kislanykim airfrance similar experience with t...                      2
# 1095  nothing tops when check france music selection...                      2
# 1096  la gastronomiein afrofoodie air france many th...                      2
#
# [1097 rows x 3 columns]

# %%
df2csv.to_csv('output.csv')
